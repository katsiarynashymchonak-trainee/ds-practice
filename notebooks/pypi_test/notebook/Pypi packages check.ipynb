# %%
pip install --upgrade future_sales_inno_ds_project
# Out:
# ...
#   Attempting uninstall: future_sales_inno_ds_project
#     Found existing installation: future_sales_inno_ds_project 0.0.13
#     Uninstalling future_sales_inno_ds_project-0.0.13:
#       Successfully uninstalled future_sales_inno_ds_project-0.0.13
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show future_sales_inno_ds_project
# Out:
# Name: future_sales_inno_ds_project
# Version: 0.0.14
# Summary: DS project
# Home-page:
# Author: Katsiaryna
# Author-email: katsiaryna.shymchonak@innowise.com
# License:
# Location: C:\Users\USER\anaconda3\Lib\site-packages
# Requires: dill, hyperopt, keras, lightgbm, neptune, numpy, openai, optuna, pandas, PyGithub, python-dotenv, requests, scikit-learn, setuptools, shap, xgboost
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from future_sales_inno_ds_project import pipeline

# %%
NEPTUNE_API_TOKEN = "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI2YTliMTVhYy1lZDVkLTRlYzUtYWI4Yi0wZjkxYmU1MTZkMmQifQ=="
pipeline.run_pipeline(NEPTUNE_API_TOKEN)
# Out:
# INFO:future_sales_inno_ds_project.pipeline:Sales Prediction Pipeline started
# [neptune] [warning] NeptuneWarning: By default, these monitoring options are disabled in interactive sessions: 'capture_stdout', 'capture_stderr', 'capture_traceback', 'capture_hardware_metrics'. You can set them to 'True' when initializing the run and the monitoring will continue until you call run.stop() or the kernel stops. NOTE: To track the source files, pass their paths to the 'source_code' argument. For help, see: https://docs-legacy.neptune.ai/logging/source_code/
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/katsiaryna.shymchonak/Future-sales/e/FUT-31
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
# ...
