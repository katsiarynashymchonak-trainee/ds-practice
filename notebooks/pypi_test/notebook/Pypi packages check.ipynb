# %%
# !conda activate ds-practice

# %%
# !python --version
# Out:
# Python 3.13.5

# %%
# !conda create -n py311-env python=3.11

# %%
# !conda activate py311-env

# %%
pip install future_sales_inno_ds_project
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached future_sales_inno_ds_project-0.0.15-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached hyperopt-0.2.7-py2.py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached keras-3.11.3-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached neptune-1.14.0-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Preparing metadata (pyproject.toml) did not run successfully.
#   exit code: 1
#
# ...

# %%
pip show future_sales_inno_ds_project
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: future_sales_inno_ds_project

# %%
from future_sales_inno_ds_project import pipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from future_sales_inno_ds_project import pipeline
#
# ModuleNotFoundError: No module named 'future_sales_inno_ds_project'

# %%
NEPTUNE_API_TOKEN = "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI2YTliMTVhYy1lZDVkLTRlYzUtYWI4Yi0wZjkxYmU1MTZkMmQifQ=="
pipeline.run_pipeline(NEPTUNE_API_TOKEN)
